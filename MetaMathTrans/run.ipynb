# %%
# %pip install requirements.txt

# %%
# !python eval_math_trans.py \
--model Qwen/Qwen2.5-0.5B \
--data_file MATH_test.jsonl \
--batch_size 128 \
--tensor_parallel_size 1

# %%
# !python eval_math_5shot.py \        
--model Qwen/Qwen2.5-0.5B \
--train_file MetaMathQA-1k.json \
--data_file MATH_test.jsonl \     
--batch_size 1
